# %% [markdown]
# ## Scraping Property Access PH through Selenium
# This notebook was prepared by Adem Inovejas, Christopher Lim, Czarina Tiu, and Uriel Grace Magtibay (students of DATA102 S11 Y2022-2023).
#
# In your notebook, make sure you have the following details outlined:
# - The website scraped
# - Date and time when the data was collected
# - What were the challenges encountered? You may narrate or illustrate this in the notebook.
# - Do you think the collected data contains any personally identifiable information (PII)?
# - Conclude with your key learnings and findings.

# %% [markdown]
# ## Importing Libaries

# %%
from bs4 import BeautifulSoup
import pandas as pd
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## Setup

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
url = "https://propertyaccess.ph/offer/sale"
driver.get(url)
print(driver.page_source)
# Out:
# <html lang="en-US"><head>
#     <title>Access the best Philippine properties available in the market, from house and lot to condominiums · PropertyAccess Philippines</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1"><meta data-n-head="ssr" data-hid="description" name="description" content=""><meta data-n-head="ssr" name="robots" content="index, follow"><meta data-n-head="ssr" data-hid="og:title" name="og:title" content="Access the best Philippine properties available in the market, from house and lot to condominiums · PropertyAccess Philippines"><meta data-n-head="ssr" data-hid="og:description" name="og:description" content="PropertyAccess provides you with easy access to the best Philippine properties, from house and lot to condominiums, and to the life and style you truly deserve. Access your dream home - made simpler with PropertyAccess."><meta data-n-head="ssr" data-hid="og:image" name="og:image" content="https://cdn.propertyaccess.ph/static/property_thumbnail.jpg"><meta data-n-head="ssr" data-hid="i18n-og" property="og:locale" content="en_US"><meta data-n-head="ssr" data-hid="i18n-og-alt-jp-JP" property="og:locale:alternate" content="jp_JP"><link data-n-head="ssr" rel="icon" href="https://assets.propertyaccess.ph/app/uploads/20210528183810/cropped-PA-Favicon-32x32.png" sizes="32x32"><link data-n-head="ssr" rel="icon" href="https://assets.propertyaccess.ph/app/uploads/20210528183810/cropped-PA-Favicon-192x192.png" sizes="192x192"><link data-n-head="ssr" rel="apple-touch-icon" href="https://assets.propertyaccess.ph/app/uploads/20210528183810/cropped-PA-Favicon-180x180.png"><link data-n-head="ssr" data-hid="gf-prefetch" rel="dns-prefetch" href="https://fonts.gstatic.com/"><link data-n-head="ssr" data-hid="gf-preload" rel="preload" as="style" href="https://fonts.googleapis.com/css2?family=Rubik:wght@200;300;400;500;600;700;800&amp;family=Montserrat:wght@200;300;400;500;600;700;800&amp;family=Yeseva One:wght@200;300;400;500;600;700;800&amp;display=swap"><link data-n-head="ssr" data-hid="i18n-alt-en" rel="alternate" href="/offer/sale" hreflang="en"><link data-n-head="ssr" data-hid="i18n-alt-en-US" rel="alternate" href="/offer/sale" hreflang="en-US"><link data-n-head="ssr" data-hid="i18n-alt-jp" rel="alternate" href="/jp/offer/sale" hreflang="jp"><link data-n-head="ssr" data-hid="i18n-alt-jp-JP" rel="alternate" href="/jp/offer/sale" hreflang="jp-JP"><link data-n-head="ssr" data-hid="i18n-xd" rel="alternate" href="/offer/sale" hreflang="x-default"><link data-n-head="ssr" data-hid="i18n-can" rel="canonical" href="/offer/sale"><script src="https://connect.facebook.net/signals/config/396094181809715?v=2.9.84&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-M62P9VR"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-XXXXXXX"></script><script data-n-head="ssr" data-hid="gtag" src="https://www.googletagmanager.com/gtag/js?id=UA-93964834-3" async=""></script><script data-n-head="ssr" data-hid="gf-script">(function(){var l=document.createElement('link');l.rel="stylesheet";l.href="https://fonts.googleapis.com/css2?family=Rubik:wght@200;300;400;500;600;700;800&family=Montserrat:wght@200;300;400;500;600;700;800&family=Yeseva One:wght@200;300;400;500;600;700;800&display=swap";document.querySelector("head").appendChild(l);})();</script><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Rubik:wght@200;300;400;500;600;700;800&amp;family=Montserrat:wght@200;300;400;500;600;700;800&amp;family=Yeseva One:wght ...
#   <meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion/757345809/?random=1664177860242&amp;cv=9&amp;fst=1664177860242&amp;num=1&amp;value=0&amp;label=vT6NCIH0wfUCEJHckOkC&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1032&amp;u_aw=1920&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2wg9l0&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fpropertyaccess.ph%2Foffer%2Fsale&amp;tiba=Access%20the%20best%20Philippine%20properties%20available%20in%20the%20market%2C%20from%20house%20and%20lot%20to%20condominiums%20%C2%B7%20PropertyAccess%20Philippines&amp;auid=1233923461.1664177860&amp;hn=www.googleadservices.com&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><style type="text/css">
# .pu-skeleton {
#   background-size: 200px 100%;
#   background-repeat: no-repeat;
#   border-radius: 3px;
#   display: inline-block;
#   line-height: 1;
#   width: 100%;
#   height: inherit;
# }
# @keyframes SkeletonLoading {
# 0% {
#     background-position: -200px 0;
# }
# 100% {
#     background-position: calc(200px + 100%) 0;
# }
# }
#
# /*# sourceURL=/Users/kit/Projects/resources/vue-loading-skeleton/src/skeleton.vue */
# /*# sourceMappingURL=data:application/json;base64,... */</style><script data-n-head="ssr" data-hid="gtm-script">if(!window._gtm_init){window._gtm_init=1;(function(w,n,d,m,e,p){w[d]=(w[d]==1||n[d]=='yes'||n[d]==1||n[m]==1||(w[e]&&w[e][p]&&w[e][p]()))?1:0})(window,navigator,'doNotTrack','msDoNotTrack','external','msTrackingProtectionEnabled');(function(w,d,s,l,x,y){w[x]={};w._gtm_inject=function(i){if(w.doNotTrack||w[x][i])return;w[x][i]=1;w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s);j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i;f.parentNode.insertBefore(j,f);};w[y]('GTM-XXXXXXX')})(window,document,'script','dataLayer','_gtm_ids','_gtm_inject')}</script><script charset="utf-8" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/5d4c96c.modern.js"></script><link rel="preload" as="style" href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/cbf88ab.css"><script charset="utf-8" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/5559b6a.modern.js"></script><link rel="preload" as="style" href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/a7b188a.css"><script charset="utf-8" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/ddf515e.modern.js"></script><link rel="preload" as="style" href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/4cae891.css"><script charset="utf-8" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/5277262.modern.js"></script><script charset="utf-8" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/d8ab7b7.modern.js"></script><script charset="utf-8" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/bb9a5cb.modern.js"></script><link rel="preload" as="style" href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/c225e92.css"><script charset="utf-8" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/196912c.modern.js"></script></head>
#   <body><noscript data-n-head="ssr" data-hid="gtm-noscript" data-pbody="true"><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-XXXXXXX&" height="0" width="0" style="display:none;visibility:hidden" title="gtm"></iframe></noscript>
#     <div id="__nuxt"><div class="loading-overlay is-active is-full-page" style="display: none;" data-v-bf64770a=""><div class="loading-background"></div><div class="loading-icon"></div></div><div id="__layout"><div><header data-v-580c9206=""><div class="header__placeholder" data-v-580c9206=""></div> <div class="header" data-v-580c9206=""><div class="header__container" data-v-580c9206=""><a href="/" class="header__logo-wrapper nuxt-link-active" data-v-580c9206=""><img src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/12067e04f92e2b8efac6a4d3cc640c7c.svg" width="248" height="248" class="header__logo" data-v-580c9206=""></a> <div class="header__mobile-nav" data-v-580c9206=""><div class="header__mobile-burger" data-v-580c9206=""><svg width="24" height="18" viewBox="0 0 24 18" fill="none" xmlns="http://www.w3.org/2000/svg" data-v-580c9206=""><path d="M1 1H23" stroke="#26B467" stroke-width="2" stroke-linecap="round" data-v-580c9206=""></path> <path d="M1 9H23" stroke="#26B467" stroke-width="2" stroke-linecap="round" data-v-580c9206=""></path> <path d="M1 17H23" stroke="#26B467" stroke-width="2" stroke-linecap="round" data-v-580c9206=""></path></svg></div></div> <nav class="header__navigation-container" data-v-580c9206=""><ul class="header__navigation" data-v-580c9206=""><li class="header__navigation-item header__navigation-item-close" data-v-580c9206=""><button class="button button--is-outlined" data-v-7c274766="" data-v-580c9206="">CLOSE</button></li> <li data-v-580c9206="" class=""><a href="/offer/sale" aria-current="page" class="nuxt-link-exact-active nuxt-link-active header__navigation-item header__navigation-item--highlight" data-v-580c9206=""><!---->
#                   BUY
#                 </a></li><li data-v-580c9206="" class=""><a href="/offer/rent" class="header__navigation-item" data-v-580c9206=""><!---->
#                   RENT
#                 </a></li><li data-v-580c9206="" class=""><div data-v-580c9206="" class="dropdown dropdown-menu-animation is-hoverable is-mobile-modal"><div role="button" tabindex="0" aria-haspopup="true" class="dropdown-trigger"><div data-v-580c9206="" class="header__navigation-item"><span data-v-580c9206="">DIRECTORY</span> <span data-v-580c9206="" class="icon"><i class="mdi mdi-menu-down mdi-24px"></i></span></div></div><div aria-hidden="true" class="background" style="display: none;"></div><div aria-hidden="true" class="dropdown-menu" style="display: none;"><div role="list" class="dropdown-content"> <a data-v-580c9206="" role="listitem" tabindex="0" class="dropdown-item"><a data-v-580c9206="" href="/developers" class="">
#                           DEVELOPERS
#                         </a></a><a data-v-580c9206="" role="listitem" tabindex="0" class="dropdown-item"><a data-v-580c9206="" href="/developments" class="">
#                           DEVELOPMENTS
#                         </a></a><a data-v-580c9206="" role="listitem" tabindex="0" class="dropdown-item"><a data-v-580c9206="" href="/neighborhoods" class="">
#                           NEIGHBORHOODS
#                         </a></a><a data-v-580c9206="" role="listitem" tabindex="0" class="dropdown-item"><a data-v-580c9206="" href="/agents" class="">
#                           AGENTS
#                         </a></a></div></div></div></li><li data-v-580c9206="" class=""><a href="/articles" class="header__navigation-item" data-v-580c9206=""><!---->
#                   ARTICLES
#                 </a></li> <li class="header__navigation-item--mobile-only" data-v-580c9206=""><span class="header__navigation-item header__navigation-item--section-title" data-v-580c9206="">ACCOUNT</span></li>  <li class="header__navigation-item--mobile-only" data-v-580c9206=""><a href="/login" class="header__navigation-item" data-v-580c9206="">Sign in</a></li></ul></nav> <div class="header__right-bar" data-v-580c9206=""><a href="/login" data-v-580c9206="" class=""><button class="button button--is-outlined" data-v-7c274766="" data-v-580c9206="">SIGN UP OR LOG IN</button></a></div></div></div></header> <div class="page-body"><div class="offer-type" data-v-59896e8c=""><div class="offer-type__banner" data-v-59896e8c=""><p class="title-text" data-v-59896e8c="">Buy Properties</p> <p class="desc-text mt-2" data-v-59896e8c="">
#       Search for the best apartments and house and lots for sale in the Philippines and start accessing your dream home and your next property investment with PropertyAccess Philippines.
#     </p> <div class="banner-overlay" data-v-59896e8c=""></div></div> <div class="ais-InstantSearch ais-InstantSearch--ssr" data-v-59896e8c=""><!----> <div style="" data-v-59896e8c=""><section class="filter-bar" data-v-59896e8c=""><div class="filter-bar_detail" data-v-59896e8c=""><div class="filter-group" data-v-59896e8c=""><div data-v-59896e8c="" class="ais-RefinementList" style="display: none;"><!----> <!----> <ul class="ais-RefinementList-list"><li class="ais-RefinementList-item ais-RefinementList-item--selected"><label class="ais-RefinementList-label"><input type="checkbox" class="ais-RefinementList-checkbox" value="For sale"> <span class="ais-RefinementList-labelText">For sale</span> <span class="ais-RefinementList-count">2278</span></label></li><li class="ais-RefinementList-item"><label class="ais-RefinementList-label"><input type="checkbox" class="ais-RefinementList-checkbox" value="For rent"> <span class="ais-RefinementList-labelText">For rent</span> <span class="ais-RefinementList-count">916</span></label></li></ul> <!----></div> <div data-v-59896e8c="" class="search-product ais-SearchBox"><div class="fa-theme"><div class="filter-label">SEARCH FOR A PROPERTY</div> <div class="control filter-content-wrapper search-input has-icons-left  is-clearfix"><input type="text" autocomplete="on" id="search-input-agolia" placeholder="Property name, Region..." class="input"><span class="icon is-left"><i class="mdi mdi-magnify mdi-24px"></i></span><!----><!----></div></div></div> <div data-v-64c35a48="" data-v-59896e8c="" class="ais-RefinementList location"><div data-v-64c35a48="" class="agolia-select filter-wrapper flex-column"><span data-v-64c35a48="" class="filter-label"> LOCATION</span> <div data-v-64c35a48="" class="dropdown dropdown-menu-animation fa-theme full-width"><div role="button" tabindex="0" aria-haspopup="true" class="dropdown-trigger"><button data-v-64c35a48="" type="button" class="button button-icon filter-content-wrapper location.city"><!----><span>All</span><span class="icon is-small"><i class="mdi mdi-menu-down"></i></span></button></div><!----><div aria-hidden="true" class="dropdown-menu" style="display: none;"><div role="list" class="dropdown-content"> <a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Las Piñas
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Makati
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Mandaluyong
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Manila
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Muntinlupa
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Parañaque
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Pasig
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Quezon City
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>San Juan
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Taguig
#         </a></div></div></div></div></div> <div data-v-64c35a48="" data-v-59896e8c="" class="ais-RefinementList property_type"><div data-v-64c35a48="" class="agolia-select filter-wrapper flex-column"><span data-v-64c35a48="" class="filter-label"> PROPERTY TYPE</span> <div data-v-64c35a48="" class="dropdown dropdown-menu-animation fa-theme full-width"><div role="button" tabindex="0" aria-haspopup="true" class="dropdown-trigger"><button data-v-64c35a48="" type="button" class="button button-icon filter-content-wrapper property_type"><!----><span>All</span><span class="icon is-small"><i class="mdi mdi-menu-down"></i></span></button></div><!----><div aria-hidden="true" class="dropdown-menu" style="display: none;"><div role="list" class="dropdown-content"> <a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Apartment
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Commercial
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Condo
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>House &amp; Lot
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Industrial
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Office
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Residential Lot
#         </a></div></div></div></div></div> <div data-v-5c391381="" data-v-59896e8c="" class="ais-RangeInput price"><div data-v-5c391381="" class="slider-wraper"><div data-v-5c391381="" class="filter-label">PRICE</div> <div data-v-5c391381="" class="filter-content"><div data-v-5c391381="" class="b-slider custom-slider fa-theme is-large is-primary is-rounded"><div class="b-slider-track"><div class="b-slider-fill" style="width: 99.988%; left: 0.000993103%;"></div><!----><div class="b-slider-thumb-wrapper" style="left: 0.000993103%;"><span class="b-tooltip is-primary is-top is-medium"><div class="tooltip-content" style="display: none;">18,000</div><div class="tooltip-trigger"><div tabindex="0" role="slider" aria-valuenow="18000" aria-valuemin="0" aria-valuemax="1812500000" aria-orientation="horizontal" class="b-slider-thumb"><!----></div></div></span></div><div class="b-slider-thumb-wrapper" style="left: 99.989%;"><span class="b-tooltip is-primary is-top is-medium"><div class="tooltip-content" style="display: none;">1,812,300,000</div><div class="tooltip-trigger"><div tabindex="0" role="slider" aria-valuenow="1812300000" aria-valuemin="0" aria-valuemax="1812500000" aria-orientation="horizontal" aria-label="" class="b-slider-thumb"><!----></div></div></span></div></div></div> <div data-v-5c391381="" class="space-between" style="height: 1em;"><div data-v-5c391381="">18,000</div> <div data-v-5c391381="">1,812,300,000</div></div></div></div></div> <div class="filter-wrapper more-filter" data-v-59896e8c=""><span style="height:24px;" data-v-59896e8c=""></span> <button type="button" class="button button-fa filter-content-wrapper style-active [object Object] " style="width:100%;" data-v-26eae570="" data-v-59896e8c=""><!----><span><div class="content" data-v-26eae570="">
#     More filters
#   </div></span><!----></button></div> <div class="filter-wrapper clear-filter" data-v-59896e8c=""><span style="height:24px;" data-v-59896e8c=""></span> <div data-v-56cfa874="" data-v-59896e8c="" class="ais-ClearRefinements"><div data-v-56cfa874=""><a data-v-26eae570="" data-v-56cfa874="" type="button" href="https://propertyaccess.ph/offer/sale" class="button button-fa filter-content-wrapper style-unactive "><!----><span><div data-v-26eae570="" class="content">
#     Clear filters
#   </div></span><!----></a></div></div></div></div> <div class="filter-group" style="display:none;" data-v-59896e8c=""><div data-v-64c35a48="" data-v-59896e8c="" class="ais-RefinementList facilities"><div data-v-64c35a48="" class="agolia-select filter-wrapper flex-column"><span data-v-64c35a48="" class="filter-label"> FACILITIES</span> <div data-v-64c35a48="" class="dropdown dropdown-menu-animation fa-theme full-width"><div role="button" tabindex="0" aria-haspopup="true" class="dropdown-trigger"><button data-v-64c35a48="" type="button" class="button button-icon filter-content-wrapper facilities"><!----><span>All</span><span class="icon is-small"><i class="mdi mdi-menu-down"></i></span></button></div><!----><div aria-hidden="true" class="dropdown-menu" style="display: none;"><div role="list" class="dropdown-content"> <a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>24-Hour Security
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>CCTV
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Club House
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Conference Room
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Connected to mall
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Daycare
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Entertainment Area
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Fitness Center
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Function Rooms
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Garden
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Golf Course Nearby
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Grand Lobby
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Helipad
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Jogging Path
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Laundry station
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Lounge
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Mailbox area
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Play Area
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Reception Area
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Roof deck/sky lounge
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Spa
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Swimming Pool
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Sauna
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Yoga Studio
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Multiple Entrances
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Air conditioning
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Central air conditioning
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Security
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Building Parking
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Storefront Parking
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Elevators
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Fiber ready
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Retail spaces
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Dining Options
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Lobby
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Building Reception Area
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Driveway
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>With Office
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>With House
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>With sleeping quarters/barracks
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>On the Road
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Inner Road
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Gated
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Pets allowed
#         </a></div></div></div></div></div> <div data-v-64c35a48="" data-v-59896e8c="" class="ais-RefinementList amenities"><div data-v-64c35a48="" class="agolia-select filter-wrapper flex-column"><span data-v-64c35a48="" class="filter-label"> AMENITIES</span> <div data-v-64c35a48="" class="dropdown dropdown-menu-animation fa-theme full-width"><div role="button" tabindex="0" aria-haspopup="true" class="dropdown-trigger"><button data-v-64c35a48="" type="button" class="button button-icon filter-content-wrapper amenities"><!----><span>All</span><span class="icon is-small"><i class="mdi mdi-menu-down"></i></span></button></div><!----><div aria-hidden="true" class="dropdown-menu" style="display: none;"><div role="list" class="dropdown-content"> <a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Balcony
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Dirty Kitchen
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Fiber ready
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Fully fenced
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Garage space
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Garden/Lanai
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Gated village
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Laundry Area
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Maid’s Quarters
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Pool
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>WiFi
#         </a></div></div></div></div></div> <div data-v-64c35a48="" data-v-59896e8c="" class="ais-RefinementList bedrooms"><div data-v-64c35a48="" class="agolia-select filter-wrapper flex-column"><span data-v-64c35a48="" class="filter-label"> BEDROOMS</span> <div data-v-64c35a48="" class="dropdown dropdown-menu-animation fa-theme full-width"><div role="button" tabindex="0" aria-haspopup="true" class="dropdown-trigger"><button data-v-64c35a48="" type="button" class="button button-icon filter-content-wrapper bedrooms"><!----><span>All</span><span class="icon is-small"><i class="mdi mdi-menu-down"></i></span></button></div><!----><div aria-hidden="true" class="dropdown-menu" style="display: none;"><div role="list" class="dropdown-content"> <a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>1
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>10
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>2
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>3
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>4
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>5
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>6
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>7
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>8
#         </a><a data-v-64c35a48="" tabindex="0" class="dropdown-item"><label data-v-64c35a48="" disabled="disabled" class="b-checkbox checkbox fa-theme is-disabled"><input type="checkbox" autocomplete="on" disabled="disabled" true-value="true" value="false"><span class="check"></span><span class="control-label"></span></label>Studio
# ...
#       </div> <div data-v-2e0782e0=""><img data-v-2e0782e0="" class="mr-1" data-src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/c4aaa23e0db8976594c94f0b94081a64.svg" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/img/white.59b5b31.png" lazy="loading"> 2
#       </div> <div data-v-2e0782e0=""><img data-v-2e0782e0="" class="mr-1" data-src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/df99d754cc348421bd8a632df3ef7b5c.svg" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/img/white.59b5b31.png" lazy="loading"> 1
#       </div> <!----></div> <div data-v-2e0782e0="" class="detail__wr"><div data-v-2e0782e0=""><img data-v-2e0782e0="" class="mr-1" data-src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/57cebe2c8bcb0aa7f604503ddb740621.svg" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/img/white.59b5b31.png" lazy="loading">
#         from 96 sqm
#       </div> <!----></div> <!----></div> <div data-v-2e0782e0="" class="facilities line-clamp lc-2"><p data-v-2e0782e0="">Facilities:</p> <div data-v-2e0782e0="">
#           Clubhouse
#         </div><div data-v-2e0782e0="">
#           Jogging Path
#         </div><div data-v-2e0782e0="">
#           Retail Area
#         </div><div data-v-2e0782e0="">
#           Swimming Pool
#         </div><div data-v-2e0782e0="">
#           Fitness Center
#         </div><div data-v-2e0782e0="">
#           Daycare
#         </div><div data-v-2e0782e0="">
#           Play Area
#         </div><div data-v-2e0782e0="">
#           Function Room
#         </div><div data-v-2e0782e0="">
#           24-Hour Security
#         </div><div data-v-2e0782e0="">
#           CCTV
#         </div><div data-v-2e0782e0="">
#           Conference Room
#         </div><div data-v-2e0782e0="">
#           Connected to mall
#         </div><div data-v-2e0782e0="">
#           Entertainment Area
#         </div><div data-v-2e0782e0="">
#           Function Rooms
#         </div><div data-v-2e0782e0="">
#           Grand Lobby
#         </div><div data-v-2e0782e0="">
#           Lounge
#         </div><div data-v-2e0782e0="">
#           Mailbox area
#         </div><div data-v-2e0782e0="">
#           Reception Area
#         </div><div data-v-2e0782e0="">
#           Spa
#         </div><div data-v-2e0782e0="">
#           Sauna
#         </div></div> <div data-v-2e0782e0="" class="mt-1"><div data-v-2e0782e0="" class="date">Published on: 5/06/2022</div></div></div> <div data-v-c8713abe="" class="product-bottom mt-2"><a data-v-c8713abe="" href="/property/2-br-condo-in-the-residences-at-the-westin-mandaluyong-zb1etf?queryID=f7c5d850168cd5c1017933a2a1591433" class=""><button data-v-26eae570="" data-v-c8713abe="" type="button" class="button button-fa filter-content-wrapper reverse view-property " style="border-radius: 16px;"><!----><span><div data-v-26eae570="" class="content">
#     View property
#   </div></span><!----></button></a></div></div></div></div></div></div> <div data-v-25ee339e="" data-v-59896e8c="" class="ais-Pagination"><div data-v-25ee339e=""><ul data-v-25ee339e="" class="pargination"><!----> <li data-v-25ee339e="" class="pages"><div data-v-25ee339e="" style="display: none;">...</div> <a data-v-25ee339e="" href="https://propertyaccess.ph/offer/sale" class="page-item" style="font-weight: bold;">
#             1
#           </a><a data-v-25ee339e="" href="https://propertyaccess.ph/offer/sale?page=2" class="page-item">
#             2
#           </a><a data-v-25ee339e="" href="https://propertyaccess.ph/offer/sale?page=3" class="page-item">
#             3
#           </a><a data-v-25ee339e="" href="https://propertyaccess.ph/offer/sale?page=4" class="page-item">
#             4
#           </a><a data-v-25ee339e="" href="https://propertyaccess.ph/offer/sale?page=5" class="page-item">
#             5
#           </a> <div data-v-25ee339e="">...</div></li> <li data-v-25ee339e="" class="next flex-end"><a data-v-25ee339e="" href="https://propertyaccess.ph/offer/sale?page=2">
#           Next <img data-v-25ee339e="" src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/16a026b13af5af162c301e4fd8da0a03.svg" class="ml-1"></a></li></ul></div></div></div> <section class="intro" data-v-59896e8c=""><div class="intro-1" data-v-59896e8c="">Your preferred online real estate platform</div> <div class="intro-2" data-v-59896e8c="">PropertyAccess is the preferred platform for anyone who wants to buy or rent real estate properties in the Philippines. Search for a house for sale, an apartment for rent, a condo for sale, and other real estate projects all over the Philippines. <br> Get complete and transparent information about a property and learn more about preferred real estate properties and developments in key areas. Our comprehensive and lifestyle-based area overviews are filled with information, such as points of interest and local insights. Read a wide array of real estate content, from home improvement to interior design to real estate news, and most importantly, real estate investment guides to advise, especially first-time buyers, how to approach real estate investment. <br> <br> PropertyAccess aims to be the preferred and trusted real estate platform for property sellers, brokers, and agents. Get support in promoting real estate properties and developments for sale and for rent from our professional listing partners. Gain a wider reach on the internet and attract more property buyers and sellers. Focus on closing the deal while we take care of inquiries and screening of leads.</div></section></div></div> <footer class="footer" data-v-4a64d996=""><div class="container" data-v-4a64d996=""><div class="footer__contact" data-v-4a64d996=""><!--fragment#f975837ee6#head--><picture fragment="2ab15de01f" data-v-3f77fe33=""><source srcset="https://media.propertyaccess.ph/cdn/255x255-webp/static/footer-logo.png" type="image/webp" class="footer__logo" data-v-3f77fe33=""> <img alt="footer" width="255" height="255" loading="lazy" class="footer__logo" data-v-3f77fe33="" data-src="https://media.propertyaccess.ph/cdn/255x255/static/footer-logo.png" src="https://media.propertyaccess.ph/cdn/255x255/static/footer-logo.png" lazy="loaded"></picture><!--fragment#f975837ee6#tail--> <div class="footer__address" data-v-4a64d996="">
#         Level 10-1 One Global Place, 25th Street &amp; 5th Avenue, Bonifacio Global City, Taguig City, 1634 Philippines.
#       </div> <div class="footer__email" data-v-4a64d996=""><a href="mailto:customercare@propertyaccess.ph" data-v-4a64d996="">
#           customercare@propertyaccess.ph</a></div> <div class="footer__socials" data-v-4a64d996=""><a href="https://facebook.com/PropertyAccessPH" class="footer__socials-item" data-v-4a64d996=""><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" data-v-4a64d996=""><path d="M13.397 20.9972V12.8012H16.162L16.573 9.59217H13.397V7.54817C13.397 6.62217 13.655 5.98817 14.984 5.98817H16.668V3.12717C15.8486 3.03936 15.025 2.99696 14.201 3.00017C11.757 3.00017 10.079 4.49217 10.079 7.23117V9.58617H7.33197V12.7952H10.085V20.9972H13.397Z" fill="white" data-v-4a64d996=""></path></svg></a> <a href="https://www.instagram.com/propertyaccessph/" class="footer__socials-item" data-v-4a64d996=""><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" data-v-4a64d996=""><path fill-rule="evenodd" clip-rule="evenodd" d="M12 7C10.6739 7 9.40215 7.52678 8.46447 8.46447C7.52678 9.40215 7 10.6739 7 12C7 13.3261 7.52678 14.5979 8.46447 15.5355C9.40215 16.4732 10.6739 17 12 17C13.3261 17 14.5979 16.4732 15.5355 15.5355C16.4732 14.5979 17 13.3261 17 12C17 10.6739 16.4732 9.40215 15.5355 8.46447C14.5979 7.52678 13.3261 7 12 7ZM9 12C9 12.7956 9.31607 13.5587 9.87868 14.1213C10.4413 14.6839 11.2044 15 12 15C12.7956 15 13.5587 14.6839 14.1213 14.1213C14.6839 13.5587 15 12.7956 15 12C15 11.2044 14.6839 10.4413 14.1213 9.87868C13.5587 9.31607 12.7956 9 12 9C11.2044 9 10.4413 9.31607 9.87868 9.87868C9.31607 10.4413 9 11.2044 9 12Z" fill="white" data-v-4a64d996=""></path> <path d="M18 5C17.7348 5 17.4804 5.10536 17.2929 5.29289C17.1054 5.48043 17 5.73478 17 6C17 6.26522 17.1054 6.51957 17.2929 6.70711C17.4804 6.89464 17.7348 7 18 7C18.2652 7 18.5196 6.89464 18.7071 6.70711C18.8946 6.51957 19 6.26522 19 6C19 5.73478 18.8946 5.48043 18.7071 5.29289C18.5196 5.10536 18.2652 5 18 5Z" fill="white" data-v-4a64d996=""></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M5 1C3.93913 1 2.92172 1.42143 2.17157 2.17157C1.42143 2.92172 1 3.93913 1 5V19C1 20.0609 1.42143 21.0783 2.17157 21.8284C2.92172 22.5786 3.93913 23 5 23H19C20.0609 23 21.0783 22.5786 21.8284 21.8284C22.5786 21.0783 23 20.0609 23 19V5C23 3.93913 22.5786 2.92172 21.8284 2.17157C21.0783 1.42143 20.0609 1 19 1H5ZM19 3H5C4.46957 3 3.96086 3.21071 3.58579 3.58579C3.21071 3.96086 3 4.46957 3 5V19C3 19.5304 3.21071 20.0391 3.58579 20.4142C3.96086 20.7893 4.46957 21 5 21H19C19.5304 21 20.0391 20.7893 20.4142 20.4142C20.7893 20.0391 21 19.5304 21 19V5C21 4.46957 20.7893 3.96086 20.4142 3.58579C20.0391 3.21071 19.5304 3 19 3Z" fill="white" data-v-4a64d996=""></path></svg></a></div></div> <div class="footer__nav footer__buyer-nav" data-v-4a64d996=""><h2 class="footer__nav-headline" data-v-4a64d996="">Buyer / Renter</h2> <ul class="footer__nav-list" data-v-4a64d996=""><a href="/offer/sale" aria-current="page" class="nuxt-link-exact-active nuxt-link-active" data-v-4a64d996=""><li data-v-4a64d996="">
#             View home <!----></li></a><a href="/offer/rent" data-v-4a64d996="" class=""><li data-v-4a64d996="">
#             View rentals <!----></li></a><a href="/" class="nuxt-link-active" data-v-4a64d996=""><li data-v-4a64d996="">
#             Buyer Guide <small class="sub" data-v-4a64d996="">Soon</small></li></a><a href="/" class="nuxt-link-active" data-v-4a64d996=""><li data-v-4a64d996="">
#             Renter Guide <small class="sub" data-v-4a64d996="">Soon</small></li></a></ul></div> <div class="footer__nav footer__developer-nav" data-v-4a64d996=""><h2 class="footer__nav-headline" data-v-4a64d996="">Agent / Developer</h2> <ul class="footer__nav-list" data-v-4a64d996=""><li data-v-4a64d996=""><a href="https://propertyaccess.ph/post-a-listing/" data-v-4a64d996="">Post a Listing</a></li><li data-v-4a64d996=""><a href="https://propertyaccess.ph/post-a-listing/" data-v-4a64d996="">How it works</a></li> <!----> <li data-v-4a64d996=""><a href="/login" data-v-4a64d996="" class="">Log in</a></li></ul></div> <div class="footer__nav footer__customer-nav" data-v-4a64d996=""><h2 class="footer__nav-headline" data-v-4a64d996="">Sign up</h2> <form class="footer__sub-form" data-v-4a64d996=""><input type="text" placeholder="Your email" data-v-4a64d996=""></form> <ul class="footer__nav-list" data-v-4a64d996=""><li data-v-4a64d996=""><a href="/privacy" data-v-4a64d996="" class="">Privacy</a></li></ul></div> <div class="footer__bottom-line" data-v-4a64d996=""></div></div> <div class="container" data-v-4a64d996=""><div class="footer__copyright" data-v-4a64d996=""><blockquote data-v-4a64d996="">Copyright © 2020 PropertyAccess Philippines</blockquote> <blockquote data-v-4a64d996="">
#         PropertyAccess Philippines Corp. (CRN CS201808135) is registered with the Securities and Exchange Commission.
#       </blockquote></div></div></footer> <!----></div></div></div><script>window.__NUXT__=(function(a,b,c,d,e,f,g,h,i){return {layout:"default",data:[{}],fetch:{},error:c,state:{ghostConfig:{url:"https:\u002F\u002Fblog.propertyaccess.ph",key:"d3018df3cabe5a8ecb08ad1a97",version:"v3"},userInfo:{},favorite:[],popup:{isActive:a},token:c,appLoading:a,progressLoading:a,timeFetchDataOption:c,checkClaimingState:a,eventMode:"DONE",dashboardLang:"en",development:{currentItem:{}},developer:{currentItem:{}},dashboard:{development_list:[],developer_list:[],user_list:[]},agent:{},i18n:{routeParams:{}}},serverRendered:true,routePath:"\u002Foffer\u002Fsale",config:{NODE_ENV:b,baseURL:"https:\u002F\u002Fapi.propertyaccess.ph\u002Fapi\u002F",ALGOLIA_KEY:"7Z31VSU3GN",ALGOLIA_SECRET:"b12422cf0ebe8f2252730591e581dd3e",ALGOLIA_PROPERTY_INDEX:d,ALGOLIA_DEVELOPMENT_INDEX:e,ALGOLIA_DEVELOPER_INDEX:f,ALGOLIA_AREA_INDEX:g,ALGOLIA_AGENT_INDEX:"agent-production",ALGOLIA_WEBINAR_INDEX:"webinar-kr-production",FB_PIXEL:396094181809715,GMAP_API_KEY:"AIzaSyByT0nOOenmNIoNk1zR7GM1RzYFsr80EeM",GTAG_ENV:b,GTAG_KEY:h,SENTRY_ENV:b,GOOGLE_ANALYTICS_KEY:"UA-93964834-3",NUXT_ENV_APP_MODE:b,recaptcha:{siteKey:"6LfI0Y0bAAAAAK5kEgLWx05WXMZMeOEOhk4_WyJZ"},gtm:{id:h},agolia:{ph:{property:d,development:e,developer:f,area:g},kr:{property:"property-kr-production",development:"development-kr-production",developer:"developer-kr-production",area:"area-kr-production"},jp:{property:"property-jp-production",development:"development-jp-production",developer:"developer-jp-production",area:"area-jp-production"}},_app:{basePath:i,assetsPath:i,cdnURL:"https:\u002F\u002Fcdn.propertyaccess.ph\u002Fprod\u002Fv1.2.5-fis-hotfix-2\u002F"}}}}(false,"production",null,"property-production","development-production","developer-production","area-production","GTM-M62P9VR","\u002F"));</script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/c2746c1.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/b340c0a.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/9ec6bbc.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/2e215f9.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/226792d.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/70aaeb7.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/4af27ab.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/1d5f64d.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/b22ae67.modern.js" defer=""></script><script src="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/5b59522.modern.js" defer=""></script>
#
#
# <link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/877e91d.css" rel="stylesheet" type="text/css"><link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/53e9eee.css" rel="stylesheet" type="text/css"><link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/b6d9ce7.css" rel="stylesheet" type="text/css"><link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/6759475.css" rel="stylesheet" type="text/css"><link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/4cae891.css" rel="stylesheet" type="text/css"><link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/cbf88ab.css" rel="stylesheet" type="text/css"><link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/a7b188a.css" rel="stylesheet" type="text/css"><link href="https://cdn.propertyaccess.ph/prod/v1.2.5-fis-hotfix-2/css/c225e92.css" rel="stylesheet" type="text/css"></body></html>

# %% [markdown]
# ## Data Collection

# %%
products_container = driver.find_element(by="xpath", value='//div[@class="list-product page-content"]')
products = products_container.find_elements(by="xpath", value='.//div[@class="product-wrapper"]')
print('Amount:', len(products))
for product in products:
    print('===================')
    name = product.find_element(by="xpath", value='.//div[@class="name"]').text
    author = product.find_element(by="xpath", value='.//span[@class="author-name"]').text
    building = product.find_element(by="xpath", value='.//span[@class="building"]').text
    address =  product.find_element(by="xpath", value='.//div[@class="address"]').text
    price =  product.find_element(by="xpath", value='.//div[@class="price"]').text
    facilities = [p.text for p in product.find_element(by="xpath", value='.//div[@class="facilities line-clamp lc-2"]').find_elements(by="tag name", value="div")]
    date = product.find_element(by="xpath", value='.//div[@class="date"]').text
    url = product.find_element(by="xpath", value='.//div[@class="product-img"]').find_element(by="tag name", value="a").get_attribute('href')
    print(name)
    print(author)  # can be categorized by land developer
    print(building)
    print(address) # can be seperated based on street, municipality, city
    print(price) # clean
    print(facilities)
    print(date)
    print(url)
# Out:
# Amount: 20
# ===================
# 3 Bedroom Condo in Aurelia Residences, Taguig
# Shang Properties
# Aurelia Residences
# McKinley Parkway, Taguig, Metro Manila
# from ₱ 107,300,000
# ['24-Hour Security', 'CCTV', 'Entertainment Area', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/3-bedroom-condo-in-aurelia-residences-taguig-SFCUHk?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 3 Bedroom Condo in Shang Residences at Wack Wack, Mandaluyong
# Shang Properties
# Shang Residences at Wack Wack
# Wack Wack Road, Mandaluyong, Metro Manila
# from ₱ 54,500,000
# ['24-Hour Security', 'CCTV', 'Club House', 'Entertainment Area', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/3-bedroom-condo-in-shang-residences-at-wack-wack-mandaluyong-gXOCBd?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 2BR Condo in Residences at The Galleon, Pasig
# Ortigas Land
# Residences at The Galleon
# ADB Avenue, Pasig, Metro Manila
# from ₱ 41,500,000
# ['Fitness Center', 'Swimming Pool', 'Lounge', 'Entertainment Area', 'Function Room', '', '', '', '', '', '', '', '', '']
# Published on: 1/06/2022
# https://propertyaccess.ph/property/2br-condo-in-residences-at-the-galleon-pasig-pI5tMu?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# Penthouse in Residences at The Galleon, Pasig
# Ortigas Land
# Residences at The Galleon
# ADB Avenue, Pasig, Metro Manila
# from ₱ 111,500,000
# ['Fitness Center', 'Swimming Pool', 'Lounge', 'Entertainment Area', 'Function Room', '', '', '', '', '', '', '', '', '']
# Published on: 1/06/2022
# https://propertyaccess.ph/property/penthouse-in-residences-at-the-galleon-pasig-hwx5nd?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 3 Bedroom Condo in Aurelia Residences, Taguig
# Shang Properties
# Aurelia Residences
# McKinley Parkway, Taguig, Metro Manila
# from ₱ 181,302,240
# ['24-Hour Security', 'CCTV', 'Entertainment Area', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 11/05/2022
# https://propertyaccess.ph/property/3-bedroom-condo-taguig-yYGebM?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 3 Bedroom Condo in Valencia Hills Tower E, Quezon City
# Federal Land, Inc.
# Valencia Hills Tower E
# Quezon City, Metro Manila
# from ₱ 19,837,000
# ['24-Hour Security', 'Fitness Center', 'CCTV']
# Published on: 6/09/2022
# https://propertyaccess.ph/property/3-bedroom-condo-in-valencia-hills-tower-e-quezon-city-UHAHYS?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 2 Bedroom Condo in Valencia Hills Tower E, Quezon City
# Federal Land, Inc.
# Valencia Hills Tower E
# Quezon City, Metro Manila
# from ₱ 12,023,000
# ['24-Hour Security', 'Fitness Center', 'CCTV']
# Published on: 6/09/2022
# https://propertyaccess.ph/property/2-bedroom-condo-in-valencia-hills-tower-e-quezon-city-iRnKMN?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 1 Bedroom Condo in Valencia Hills Tower E, Quezon City
# Federal Land, Inc.
# Valencia Hills Tower E
# Quezon City, Metro Manila
# from ₱ 9,534,000
# ['24-Hour Security', 'Fitness Center', 'CCTV']
# Published on: 6/09/2022
# https://propertyaccess.ph/property/1-bedroom-condo-in-valencia-hills-tower-e-quezon-city-lQ7bGX?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 3 Bedroom Condo in Aurelia Residences, Taguig
# Shang Properties
# The Rise Makati
# Yakal, Makati, Kalakhang Maynila
# from ₱ 166,584,992
# ['24-Hour Security', 'CCTV', 'Conference Room', 'Entertainment Area', '', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/3-bedroom-condo-in-aurelia-residences-taguig-2UOQjg?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 2 Bedroom Condo in The Rise Makati, Makati
# Shang Properties
# The Rise Makati
# Yakal, Makati, Kalakhang Maynila
# from ₱ 21,880,000
# ['24-Hour Security', 'CCTV', 'Conference Room', 'Entertainment Area', '', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/2-bedroom-condo-in-the-rise-makati-makati-OelXKj?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 3 Bedroom Condo in Aurelia Residences, Taguig
# Shang Properties
# Aurelia Residences
# McKinley Parkway, Taguig, Metro Manila
# from ₱ 136,850,000
# ['24-Hour Security', 'CCTV', 'Entertainment Area', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/3-bedroom-condo-in-aurelia-residences-taguig-zMO6pJ?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 2 Bedroom Condo in Shang Residences at Wack Wack, Mandaluyong
# Shang Properties
# Shang Residences at Wack Wack
# Wack Wack Road, Mandaluyong, Metro Manila
# from ₱ 40,000,000
# ['24-Hour Security', 'CCTV', 'Club House', 'Entertainment Area', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/2-bedroom-condo-in-shang-residences-at-wack-wack-mandaluyong-hvUYfZ?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 1 Bedroom Condo in Shang Residences at Wack Wack, Mandaluyong
# Shang Properties
# Shang Residences at Wack Wack
# Wack Wack Road, Mandaluyong, Metro Manila
# from ₱ 19,900,000
# ['24-Hour Security', 'CCTV', 'Club House', 'Entertainment Area', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/1-bedroom-condo-in-shang-residences-at-wack-wack-mandaluyong-hndXni?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 1BR Condo in Residences at The Galleon, Pasig
# Ortigas Land
# Residences at The Galleon
# ADB Avenue, Pasig, Metro Manila
# from ₱ 26,500,000
# ['Fitness Center', 'Swimming Pool', 'Lounge', 'Entertainment Area', 'Function Room', '', '', '', '', '', '', '', '', '']
# Published on: 1/06/2022
# https://propertyaccess.ph/property/1br-condo-in-residences-at-the-galleon-pasig-68N80F?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 1 Bedroom Condo in The Rise, Makati
# Shang Properties
# The Rise Makati
# Yakal, Makati, Kalakhang Maynila
# from ₱ 8,059,963
# ['24-Hour Security', 'CCTV', 'Conference Room', 'Entertainment Area', '', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/1-bedroom-condo-in-the-rise-makati-3dTM5F?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# Studio Condo in The Rise, Makati City
# Shang Properties
# The Rise Makati
# Yakal, Makati, Kalakhang Maynila
# from ₱ 7,538,571
# ['24-Hour Security', 'CCTV', 'Conference Room', 'Entertainment Area', '', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 17/07/2022
# https://propertyaccess.ph/property/studio-condo-in-the-rise-makati-IAQHdW?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 1 Bedroom Condo in The Grand Midori Ortigas, Pasig
# Federal Land Inc
# The Grand Midori Ortigas
# Jade Drive, Pasig, Metro Manila
# from ₱ 10,200,000
# ['Grand Lobby', 'Lounge', 'Yoga Studio', 'Entertainment Area', 'Conference Room', '', '', '', '']
# Published on: 29/03/2022
# https://propertyaccess.ph/property/1br-condo-in-the-grand-midori-ortigas-pasig-kRTdYf?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 3 BR Condo in The Grand Midori Ortigas, Pasig
# Federal Land Inc
# The Grand Midori Ortigas
# Jade Drive, Pasig, Metro Manila
# from ₱ 29,700,000
# ['Grand Lobby', 'Lounge', 'Yoga Studio', 'Entertainment Area', 'Conference Room', '', '', '', '']
# Published on: 29/03/2022
# https://propertyaccess.ph/property/3-br-condo-in-the-grand-midori-ortigas-pasig-HFRhw4?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 3 BR Condo in The Residences at The Westin, Mandaluyong
# RLC Residences
# The Residences at The Westin Manila Sonata
# Lourdes, Pasig, Metro Manila
# from ₱ 40,700,000
# ['Clubhouse', 'Jogging Path', 'Retail Area', 'Swimming Pool', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 1/06/2022
# https://propertyaccess.ph/property/3-br-condo-in-the-residences-at-the-westin-mandaluyong-S66DW8?queryID=cb9f8f11d1a5032b015696bf9f6adf54
# ===================
# 2 BR Condo in The Residences at The Westin, Mandaluyong
# RLC Residences
# The Residences at The Westin Manila Sonata
# Lourdes, Pasig, Metro Manila
# from ₱ 23,900,000
# ['Clubhouse', 'Jogging Path', 'Retail Area', 'Swimming Pool', 'Fitness Center', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# Published on: 5/06/2022
# https://propertyaccess.ph/property/2-br-condo-in-the-residences-at-the-westin-mandaluyong-zb1etf?queryID=cb9f8f11d1a5032b015696bf9f6adf54

# %%
driver.close()

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Exporting the Data

# %% [markdown]
# ## Challenges

# %% [markdown]
# ## Conclusion
